# %%
import matplotlib.pyplot as plt
import numpy as np

import maria

# %%
import maria
mustang_2 = maria.get_array("MUSTANG-2")
stare = maria.get_pointing("STARE_0az_90el_60s")
green_bank = maria.get_site("GBT")

sim = maria.Simulation(array=mustang_2, pointing=stare, site=green_bank)

tod = sim.run()
# Out:
# Computing weights: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 172.73it/s]
# Generating layers: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:00<00:00, 23368.53it/s]
# Sampling layers: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 39.43it/s]

# %%
m2 = maria.get_array("MUSTANG-2")

# %%
mustang_2  = maria.get_array("ACT_PA4")
stare      = maria.get_pointing("STARE_0az_90el_60s")
green_bank = maria.get_site("GBT")

sim = maria.Simulation(array=mustang_2, pointing=stare, site=green_bank)

tod = sim.run()
# Out:
# Computing weights: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 95.68it/s]
# Generating layers: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 1297/1297 [00:00<00:00, 14025.89it/s]
# Sampling layers: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  5.39it/s]

# %%
import scipy as sp

plt.plot(sp.signal.detrend(tod.data - tod.data.mean(axis=0)[None]).T)
plt.show()

# %%
plt.scatter(sim.array.dets.sky_x, sim.array.dets.sky_y)

# %%
plt.plot(tod.data[0])

# %%
mustang_2.detectors
# Out:
# {'93GHz': [93000000000.0, 10000000000.0, 217]}

# %%
sim = get_sim(a=False)
# Out:
# [<class '__main__.ParentB'>]

# %%
sim.vala
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 sim.vala
#
# AttributeError: 'Simulation' object has no attribute 'vala'

# %%
sim = maria.sim(array=m2, 
                pointing=daisy, 
                site=gbt, 
                noise_model="white",
                atmosphere_model="linear_angular",
                map_file="protocluster.fits",)

tod = sim.run()

# %%
#self.atm_sim = atmosphere.LinearAngularModel()

#self.run_atmosphere()

# %%
m2 = maria.get_array("MUSTANG-2")
m2.description
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 m2 = maria.get_array("MUSTANG-2")
#       2 m2.description
#
# NameError: name 'maria' is not defined
