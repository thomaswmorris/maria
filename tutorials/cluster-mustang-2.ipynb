# %% [markdown]
# ## Simulating observations with MUSTANG-2
#
# MUSTANG-2 is a bolometric array on the [Green Bank Telescope](https://en.wikipedia.org/wiki/Green_Bank_Telescope). In this notebook we simulate an observation of a galactic cluster.

# %%
import maria

map_filename = maria.io.fetch("maps/small_cluster.h5")

input_map = maria.map.load(
    nu=930e9,
    filename=map_filename,  # filename
    width=6 / 60,  # width in degrees
    center=(144, 12),  # position in the sky
    frame="ra_dec",
    units="Jy/pixel",  # units of the input map
)

input_map.plot()
# Out:
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/maps/small_cluster.h5:   0%|          | 0.00/3.45M [00:00<?, ?B/s]
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/maps/small_cluster.h5: 100%|██████████| 3.45M/3.45M [00:00<00:00, 40.3MB/s]

# %%
plan = maria.get_plan(
    scan_pattern="daisy",  # scanning pattern
    scan_options={"radius": 2 / 60, "speed": 0.5 / 60},  # in degrees
    duration=1200,  # integration time in seconds
    sample_rate=50,  # in Hz
    scan_center=(144, 12),  # position in the sky
    frame="ra_dec",
)

plan.plot()

# %%
instrument = maria.get_instrument("MUSTANG-2")
print(instrument)
instrument.plot()
# Out:
# Instrument(1 array)
# ├ arrays:
# │            n         FOV baseline      bands polarized
# │  array1  217  4.2 arcmin      0 m  [m2/f093]     False
# │
# └ bands:
#          name     center      width    η      NEP      NET_RJ     NET_CMB  \
#    0  m2/f093  86.21 GHz  20.98 GHz  0.1  30 aW√s  1.142 mK√s  1.381 mK√s
#
#               FWHM
#    0  9.133 arcsec

# %%
sim = maria.Simulation(
    instrument,
    plan=plan,
    site="green_bank",
    map=input_map,
    atmosphere="2d",
)

print(sim)
# Out:
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/atmosphere/spectra/am/v2/green_bank.h5:   0%|          | 0.00/11.1M [00:00<?, ?B/s]
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/atmosphere/spectra/am/v2/green_bank.h5:  53%|█████▎    | 5.85M/11.1M [00:00<00:00, 58.5MB/s]
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/atmosphere/spectra/am/v2/green_bank.h5: 100%|██████████| 11.1M/11.1M [00:00<00:00, 87.3MB/s]
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/atmosphere/weather/era5/green_bank.h5:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/atmosphere/weather/era5/green_bank.h5:  47%|████▋     | 5.66M/12.0M [00:00<00:00, 56.5MB/s]
# Downloading https://github.com/thomaswmorris/maria-data/raw/master/atmosphere/weather/era5/green_bank.h5: 100%|██████████| 12.0M/12.0M [00:00<00:00, 89.1MB/s]
# Constructing atmosphere:   0%|          | 0/10 [00:00<?, ?it/s]
# Constructing atmosphere:  10%|█         | 1/10 [00:01<00:09,  1.08s/it]
# Constructing atmosphere:  20%|██        | 2/10 [00:02<00:10,  1.27s/it]
# Constructing atmosphere:  30%|███       | 3/10 [00:03<00:08,  1.19s/it]
# Constructing atmosphere:  40%|████      | 4/10 [00:04<00:07,  1.20s/it]
# Constructing atmosphere:  50%|█████     | 5/10 [00:05<00:05,  1.17s/it]
# Constructing atmosphere:  60%|██████    | 6/10 [00:07<00:04,  1.20s/it]
# Constructing atmosphere:  70%|███████   | 7/10 [00:08<00:03,  1.18s/it]
# Constructing atmosphere:  80%|████████  | 8/10 [00:09<00:02,  1.15s/it]
# Constructing atmosphere:  90%|█████████ | 9/10 [00:10<00:01,  1.14s/it]
# Constructing atmosphere: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Constructing atmosphere: 100%|██████████| 10/10 [00:11<00:00,  1.16s/it]
# Simulation
# ├ Instrument(1 array)
# │ ├ arrays:
# │ │            n         FOV baseline      bands polarized
# │ │  array1  217  4.2 arcmin      0 m  [m2/f093]     False
# │ │
# │ └ bands:
# │          name     center      width    η      NEP      NET_RJ     NET_CMB  \
# │    0  m2/f093  86.21 GHz  20.98 GHz  0.1  30 aW√s  1.142 mK√s  1.381 mK√s
# │
# │               FWHM
# │    0  9.133 arcsec
# ├ Site:
# │   region: green_bank
# │   location: 38°25’59.16”N 79°50’23.28”W
# │   altitude: 0.825 km
# │   seasonal: True
# │   diurnal: True
# ├ Plan:
# │   start_time: 2024-02-10 06:00:00.000 +00:00
# │   duration: 1200 s
# │   sample_rate: 50 Hz
# │   center:
# │     ra: 09ʰ36ᵐ0.00ˢ
# │     dec: 12°00’0.00”
# │   scan_pattern: daisy
# │   scan_radius: 4 arcmin
# │   scan_kwargs: {'radius': 0.03333333333333333, 'speed': 0.008333333333333333}
# ├ Atmosphere(10 processes with 10 layers):
# │ ├ spectrum:
# │ │   region: green_bank
# │ └ weather:
# │     region: green_bank
# │     altitude: 0.825 km
# │     time: Feb 10 01:09:59 -05:00
# │     pwv[mean, rms]: (8.097 mm, 242.9 um)
# └ ProjectedMap:
#     shape[stokes, nu, t, y, x]: (1, 1, 1, 1000, 1000)
#     stokes: I
#     nu: [0.93] THz
#     t: [1.74501855e+09] s
#     quantity: rayleigh_jeans_temperature
#     units: K_RJ
#       min: -1.831e-02
#       max: -1.746e-05
#     center:
#       ra: 09ʰ36ᵐ0.00ˢ
#       dec: 12°00’0.00”
#     size[y, x]: (6 arcmin, 6 arcmin)
#     resolution[y, x]: (360 marcsec, 360 marcsec)
#     memory: 8 MB

# %%
tod = sim.run()
tod.plot()
# Out:
# Generating turbulence:   0%|          | 0/10 [00:00<?, ?it/s]
# Generating turbulence:  40%|████      | 4/10 [00:00<00:00, 34.23it/s]
# Generating turbulence:  80%|████████  | 8/10 [00:00<00:00, 24.65it/s]
# Generating turbulence: 100%|██████████| 10/10 [00:00<00:00, 23.13it/s]
# Sampling turbulence:   0%|          | 0/10 [00:00<?, ?it/s]
# Sampling turbulence:  10%|█         | 1/10 [00:00<00:02,  3.68it/s]
# Sampling turbulence:  20%|██        | 2/10 [00:00<00:02,  3.81it/s]
# Sampling turbulence:  30%|███       | 3/10 [00:00<00:01,  3.84it/s]
# Sampling turbulence:  40%|████      | 4/10 [00:01<00:01,  3.87it/s]
# Sampling turbulence:  50%|█████     | 5/10 [00:01<00:01,  3.88it/s]
# Sampling turbulence:  60%|██████    | 6/10 [00:01<00:01,  3.86it/s]
# Sampling turbulence:  70%|███████   | 7/10 [00:01<00:00,  3.87it/s]
# Sampling turbulence:  80%|████████  | 8/10 [00:02<00:00,  3.87it/s]
# Sampling turbulence:  90%|█████████ | 9/10 [00:02<00:00,  3.87it/s]
# Sampling turbulence: 100%|██████████| 10/10 [00:02<00:00,  3.83it/s]
# Sampling turbulence: 100%|██████████| 10/10 [00:02<00:00,  3.85it/s]
# Computing atmospheric emission:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing atmospheric emission:   0%|          | 0/1 [00:00<?, ?it/s, band=m2/f093]
# Computing atmospheric emission: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it, band=m2/f093]
# Computing atmospheric emission: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it, band=m2/f093]
# Sampling map:   0%|          | 0/1 [00:00<?, ?it/s]
# Sampling map:   0%|          | 0/1 [00:00<?, ?it/s, band=m2/f093]
# Sampling map:   0%|          | 0/1 [00:00<?, ?it/s, channel=[0 Hz, inf QHz]]
# Sampling map:   0%|          | 0/1 [00:02<?, ?it/s, band=m2/f093, stokes=I]
# Sampling map: 100%|██████████| 1/1 [00:03<00:00,  3.88s/it, band=m2/f093, stokes=I]
# Sampling map: 100%|██████████| 1/1 [00:03<00:00,  3.88s/it, band=m2/f093, stokes=I]
# Generating noise:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating noise:   0%|          | 0/1 [00:00<?, ?it/s, band=m2/f093]
# Generating noise: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s, band=m2/f093]
# Generating noise: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s, band=m2/f093]

# %%
from maria.mappers import BinMapper

mapper = BinMapper(
    center=(144, 12),
    frame="ra_dec",
    width=6 / 60,
    height=6 / 60,
    resolution=0.03 / 60,
    tod_preprocessing={
        "window": {"name": "hamming"},
        "remove_modes": {"modes_to_remove": [0]},
        "remove_spline": {"knot_spacing": 30, "remove_el_gradient": True},
    },
    map_postprocessing={
        "gaussian_filter": {"sigma": 1},
        "median_filter": {"size": 1},
    },
    units="uK_RJ",
)

mapper.add_tods(tod)
output_map = mapper.run()
# Out:
# Mapping band m2/f093:   0%|          | 0/1 [00:00<?, ?it/s]
# Mapping band m2/f093:   0%|          | 0/1 [00:00<?, ?it/s, band=m2/f093, stokes=I]
# Mapping band m2/f093: 100%|██████████| 1/1 [00:09<00:00,  9.06s/it, band=m2/f093, stokes=I]
# Mapping band m2/f093: 100%|██████████| 1/1 [00:09<00:00,  9.06s/it, band=m2/f093, stokes=I]
# 2025-05-10 18:01:39.595 INFO: Ran mapper for band m2/f093 in 12.75 s.

# %%
output_map.plot()
output_map.to_fits("/tmp/simulated_mustang_map.fits")
